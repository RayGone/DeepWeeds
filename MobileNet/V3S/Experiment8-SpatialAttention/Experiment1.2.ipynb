# model.predict
#   0%|          | 0/219 [00:00<?, ?it/s]
# Evaluation Metrics
# =================================
#
#                 precision    recall  f1-score   support
#
#   Chinee apple    0.82326   0.78667   0.80455       225
#        Lantana    0.89340   0.82629   0.85854       213
#    Parkinsonia    0.95000   0.92233   0.93596       206
#     Parthenium    0.94211   0.87745   0.90863       204
# Prickly acacia    0.87615   0.90094   0.88837       212
#    Rubber vine    0.92424   0.90594   0.91500       202
#      Siam weed    0.94118   0.89302   0.91647       215
#     Snake weed    0.81000   0.79803   0.80397       203
#       Negative    0.92660   0.95609   0.94111      1822
#
#       accuracy                        0.91148      3502
#      macro avg    0.89855   0.87409   0.88584      3502
#   weighted avg    0.91116   0.91148   0.91096      3502
#
#
#                 False Positive Rate  Accuracy
# Chinee apple               0.011596  0.786667
# Lantana                    0.006385  0.826291
# Parkinsonia                0.003034  0.922330
# Parthenium                 0.003335  0.877451
# Prickly acacia             0.008207  0.900943
# Rubber vine                0.004545  0.905941
# Siam weed                  0.003651  0.893023
# Snake weed                 0.011519  0.798030
# Negative                   0.082143  0.956092
#
# Confusion Matrix
# =================================

# %%
a, b = eval_model(model, test_generator)
# Out:
# model.evaluate
# 219/219 [==============================] - 4s 17ms/step - loss: 3.4289 - accuracy: 0.4810
# model.predict
#   0%|          | 0/219 [00:00<?, ?it/s]
# Evaluation Metrics
# =================================
#
#                 precision    recall  f1-score   support
#
#   Chinee apple    0.08738   0.04000   0.05488       225
#        Lantana    0.16216   0.05634   0.08362       213
#    Parkinsonia    0.21429   0.01456   0.02727       206
#     Parthenium    0.18182   0.04878   0.07692       205
# Prickly acacia    0.11111   0.01408   0.02500       213
#    Rubber vine    0.14474   0.05446   0.07914       202
#      Siam weed    0.18868   0.04651   0.07463       215
#     Snake weed    0.14444   0.06404   0.08874       203
#       Negative    0.53603   0.88633   0.66805      1821
#
#       accuracy                        0.48102      3503
#      macro avg    0.19674   0.13612   0.13092      3503
#   weighted avg    0.35242   0.48102   0.37780      3503
#
#
#                 False Positive Rate  Accuracy
# Chinee apple               0.028676  0.040000
# Lantana                    0.018845  0.056338
# Parkinsonia                0.003336  0.014563
# Parthenium                 0.013645  0.048780
# Prickly acacia             0.007295  0.014085
# Rubber vine                0.019691  0.054455
# Siam weed                  0.013078  0.046512
# Snake weed                 0.023333  0.064039
# Negative                   0.830559  0.886326
#
# Confusion Matrix
# =================================

# %% [markdown]
# # Trial 2 - Freezing Base Model

# %%
# weights = getWeightedClass(data_info, 1/2)
# print("Using Class-Weights",weights)

for layer in model.layers:
    if('mobilenet' in layer.name.lower()):
        print("Freezing Layer", layer.name)
        layer.trainable = False
        break

model.compile(loss='categorical_crossentropy',
  optimizer=AdamW(learning_rate=1e-6,  weight_decay=5e-4),
  metrics=['accuracy'])

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=0.5, patience=3, verbose=1, min_lr=5e-7)
# Train the model
history2 = model.fit(
      train_generator,
      epochs=EPOCHS,
      validation_data=validation_generator,
      callbacks=[early_stopping,reduce_lr]
    )

print("Saving the Model")
model.save(model.name+".keras")

# Plot training results
plot_loss_acc(history2.history)
# Out:
# Freezing Layer MobilenetV3small_base_
# Epoch 1/200
# 329/329 [==============================] - 21s 45ms/step - loss: 0.3424 - accuracy: 0.8800 - val_loss: 0.2488 - val_accuracy: 0.9158 - lr: 1.0000e-06
# Epoch 2/200
# 329/329 [==============================] - 14s 42ms/step - loss: 0.3124 - accuracy: 0.8919 - val_loss: 0.2521 - val_accuracy: 0.9132 - lr: 1.0000e-06
# Epoch 3/200
# 329/329 [==============================] - 14s 41ms/step - loss: 0.3143 - accuracy: 0.8910 - val_loss: 0.2555 - val_accuracy: 0.9112 - lr: 1.0000e-06
# Epoch 4/200
# 328/329 [============================>.] - ETA: 0s - loss: 0.3051 - accuracy: 0.8934
# Epoch 4: ReduceLROnPlateau reducing learning rate to 5e-07.
# 329/329 [==============================] - 14s 41ms/step - loss: 0.3053 - accuracy: 0.8934 - val_loss: 0.2598 - val_accuracy: 0.9118 - lr: 1.0000e-06
# Epoch 5/200
# 329/329 [==============================] - 14s 42ms/step - loss: 0.3047 - accuracy: 0.8943 - val_loss: 0.2618 - val_accuracy: 0.9123 - lr: 5.0000e-07
# Epoch 6/200
# 329/329 [==============================] - 14s 41ms/step - loss: 0.2858 - accuracy: 0.9001 - val_loss: 0.2632 - val_accuracy: 0.9132 - lr: 5.0000e-07
# Epoch 7/200
# 329/329 [==============================] - 14s 41ms/step - loss: 0.2949 - accuracy: 0.8965 - val_loss: 0.2655 - val_accuracy: 0.9126 - lr: 5.0000e-07
# Epoch 8/200
# 329/329 [==============================] - 13s 41ms/step - loss: 0.2825 - accuracy: 0.8998 - val_loss: 0.2672 - val_accuracy: 0.9121 - lr: 5.0000e-07
# Epoch 9/200
# 329/329 [==============================] - 14s 41ms/step - loss: 0.2923 - accuracy: 0.8998 - val_loss: 0.2690 - val_accuracy: 0.9118 - lr: 5.0000e-07
# Epoch 10/200
# 329/329 [==============================] - 14s 41ms/step - loss: 0.3024 - accuracy: 0.8977 - val_loss: 0.2710 - val_accuracy: 0.9109 - lr: 5.0000e-07
# Epoch 11/200
# 329/329 [==============================] - ETA: 0s - loss: 0.2900 - accuracy: 0.8978Restoring model weights from the end of the best epoch: 1.
# 329/329 [==============================] - 14s 42ms/step - loss: 0.2900 - accuracy: 0.8978 - val_loss: 0.2728 - val_accuracy: 0.9109 - lr: 5.0000e-07
# Epoch 11: early stopping
# Saving the Model
# Total Epochs: range(0, 11)

# %% [markdown]
# # Evaluations

# %%
import copy

history = copy.deepcopy(history1.history)

for key in history:
    history[key].extend(history2.history[key])


h1len = len(history1.history['accuracy'])
h2len = len(history2.history['accuracy'])

pat_es +=1
history['peaks'] = [h1len-pat_es, (h1len+h2len)-pat_es]
history['peaks'] = [i if i>=0 else 0 for i in history['peaks']]

plot_loss_acc(history)
# Out:
# Total Epochs: range(0, 63)

# %%
plot_loss_acc(history1.history)
plot_loss_acc(history2.history)
# Out:
# Total Epochs: range(0, 52)
# Total Epochs: range(0, 11)

# %%
## Computing Positive Threshold Using Validation Dataset
a, b = eval_model(model,validation_generator)
# Out:
# model.evaluate
# 219/219 [==============================] - 3s 15ms/step - loss: 0.2488 - accuracy: 0.9158
# model.predict
#   0%|          | 0/219 [00:00<?, ?it/s]
# Evaluation Metrics
# =================================
#
#                 precision    recall  f1-score   support
#
#   Chinee apple    0.82243   0.78222   0.80182       225
#        Lantana    0.93443   0.80282   0.86364       213
#    Parkinsonia    0.93301   0.94660   0.93976       206
#     Parthenium    0.81933   0.95588   0.88235       204
# Prickly acacia    0.86900   0.93868   0.90249       212
#    Rubber vine    0.94089   0.94554   0.94321       202
#      Siam weed    0.84146   0.96279   0.89805       215
#     Snake weed    0.79091   0.85714   0.82270       203
#       Negative    0.96534   0.93249   0.94863      1822
#
#       accuracy                        0.91576      3502
#      macro avg    0.87964   0.90269   0.88918      3502
#   weighted avg    0.91891   0.91576   0.91614      3502
#
#
#                 False Positive Rate  Accuracy
# Chinee apple               0.011596  0.782222
# Lantana                    0.003649  0.802817
# Parkinsonia                0.004248  0.946602
# Parthenium                 0.013038  0.955882
# Prickly acacia             0.009119  0.938679
# Rubber vine                0.003636  0.945545
# Siam weed                  0.011865  0.962791
# Snake weed                 0.013944  0.857143
# Negative                   0.036310  0.932492
#
# Confusion Matrix
# =================================

# %% [markdown]
# ## Test Set Evaluation

# %%
print("Normal Evaluation \
  \n--------------------------------------------------------------------")
a, b = eval_model(model, test_generator)
# Out:
# Normal Evaluation
# --------------------------------------------------------------------
# model.evaluate
# 219/219 [==============================] - 4s 16ms/step - loss: 0.2191 - accuracy: 0.9295
# model.predict
#   0%|          | 0/219 [00:00<?, ?it/s]
# Evaluation Metrics
# =================================
#
#                 precision    recall  f1-score   support
#
#   Chinee apple    0.87736   0.82667   0.85126       225
#        Lantana    0.97790   0.83099   0.89848       213
#    Parkinsonia    0.92925   0.95631   0.94258       206
#     Parthenium    0.86087   0.96585   0.91034       205
# Prickly acacia    0.92558   0.93427   0.92991       213
#    Rubber vine    0.93269   0.96040   0.94634       202
#      Siam weed    0.85833   0.95814   0.90549       215
#     Snake weed    0.79018   0.87192   0.82904       203
#       Negative    0.96687   0.94563   0.95614      1821
#
#       accuracy                        0.92949      3503
#      macro avg    0.90211   0.91669   0.90773      3503
#   weighted avg    0.93199   0.92949   0.92978      3503
#
#
#                 False Positive Rate  Accuracy
# Chinee apple               0.007932  0.826667
# Lantana                    0.001216  0.830986
# Parkinsonia                0.004550  0.956311
# Parthenium                 0.009703  0.965854
# Prickly acacia             0.004863  0.934272
# Rubber vine                0.004241  0.960396
# Siam weed                  0.010341  0.958140
# Snake weed                 0.014242  0.871921
# Negative                   0.035077  0.945634
#
# Confusion Matrix
# =================================

# %% [markdown]
# ## Random Guess Threshold
# > As applied by the paper DeepWeeds

# %%
rand_guess = 0.11
print("Evaluation with Random Guess - As applied by the paper DeepWeeds \
  \n--------------------------------------------------------------------")
printStats(a,b,rand_guess)
# Out:
# Evaluation with Random Guess - As applied by the paper DeepWeeds
# --------------------------------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       1 rand_guess = 0.11
#       2 print("Evaluation with Random Guess - As applied by the paper DeepWeeds \
#       3   \n--------------------------------------------------------------------")
# ----> 4 printStats(a,b,rand_guess)
#
# Cell In[10], line 37, in printStats(actual_labels, prediction, use_rand_guess)
#      35 def printStats(actual_labels,prediction, use_rand_guess= 0):
#      36     if use_rand_guess:
# ---> 37         prediction = [prediction_argmax(x, rand_guess=use_rand_guess) for x in prediction]
#      38     else:
#      39         prediction = [np.argmax(x) for x in prediction]
#
# Cell In[10], line 37, in <listcomp>(.0)
#      35 def printStats(actual_labels,prediction, use_rand_guess= 0):
#      36     if use_rand_guess:
# ---> 37         prediction = [prediction_argmax(x, rand_guess=use_rand_guess) for x in prediction]
#      38     else:
#      39         prediction = [np.argmax(x) for x in prediction]
#
# Cell In[10], line 6, in prediction_argmax(prediction, rand_guess)
#       5 def prediction_argmax(prediction, rand_guess=1):
# ----> 6     l_pred = np.argmax(prediction[low_data_labels])
#       7     if(prediction[l_pred] > rand_guess):
#       8         return l_pred
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/ops/array_ops.py:961, in _check_index(idx)
#     956 dtype = getattr(idx, "dtype", None)
#     957 if (dtype is None or dtypes.as_dtype(dtype) not in _SUPPORTED_SLICE_DTYPES or
#     958     idx.shape and len(idx.shape) == 1):
#     959   # TODO(slebedev): IndexError seems more appropriate here, but it
#     960   # will break `_slice_helper` contract.
# --> 961   raise TypeError(_SLICE_TYPE_ERROR + ", got {!r}".format(idx))
#
# TypeError: Only integers, slices (`:`), ellipsis (`...`), tf.newaxis (`None`) and scalar tf.int32/tf.int64 tensors are valid indices, got array([0, 1, 7, 6, 4, 3, 5, 2])

# %%
shutil.rmtree(base_dir)
